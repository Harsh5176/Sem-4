# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b>
#     <b><h1>Harsh Vekariya || 23010101297 || 12-02-2025</b>
# </center>
# <center><b><h1>Lab - 11</b></center>
# <pre>

# %% [markdown]
# # Modules

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
# main.py
import calculator

a = 10
b = 5

print("Addition:", calculator.add(a, b))
print("Subtraction:", calculator.sub(a, b))
print("Multiplication:", calculator.mul(a, b))
print("Division:", calculator.div(a, b))
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random

string = input("Enter a String :-")
random_char = random.choice(string)
print("Random Character:", random_char)
# Out:
# Enter a String :- sdasdqaw
# Random Character: d

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
import random

my_list = [10, 20, 30, 40, 50]
random_element = random.choice(my_list)
print("Random Element:", random_element)
# Out:
# Enter a List :- 10 20 320 564 85
# Random Element: ['10', '20', '320', '564', '85']

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
import random

# def roll_dice():
#     return 6  

# print("Dice Roll:", roll_dice())


random.seed(42)  
print("Dice Roll:", random.randint(1, 6))
# Out:
# Dice Roll: 6

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random

random_numbers = [random.choice(range(100, 1000, 5)) for _ in range(3)]
print("Random Numbers Divisible by 5:", random_numbers)

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
import random

lottery_tickets = [random.randint(100000, 999999) for _ in range(100)]
winners = random.sample(lottery_tickets, 2)

print("Winner:", winners[0])
print("Runner-up:", winners[1])

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
from datetime import datetime

current_time = datetime.now()
print("Current Date and Time:", current_time)

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
from datetime import datetime, timedelta

given_date = datetime(2024, 2, 12)  
new_date = given_date - timedelta(days=7)
print("Date After Subtracting a Week:", new_date)

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
from datetime import datetime

date1 = input("Enter first date (YYYY-MM-DD): ")
date2 = input("Enter second date (YYYY-MM-DD): ")

d1 = datetime.strptime(date1, "%Y-%m-%d")
d2 = datetime.strptime(date2, "%Y-%m-%d")

days_difference = abs((d2 - d1).days)
print(f"Number of days between {date1} and {date2} is {days_difference} days.")

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
from datetime import datetime

date_str = input("Enter a date (YYYY-MM-DD): ")
date_obj = datetime.strptime(date_str, "%Y-%m-%d")

day_of_week = date_obj.strftime("%A")  
print(f"The day of the week for {date_str} is {day_of_week}.")

# %% [markdown]
# ### 11) WAP to demonstrate the use of date time module.

# %%
from datetime import datetime, timedelta

# Current date and time
now = datetime.now()
print("Current Date and Time:", now)

# Formatting date
formatted_date = now.strftime("%Y-%m-%d %H:%M:%S")
print("Formatted Date:", formatted_date)

# Adding 7 days to current date
future_date = now + timedelta(days=7)
print("Date After 7 Days:", future_date.strftime("%Y-%m-%d"))

# Getting only date and time separately
print("Today's Date:", now.date())
print("Current Time:", now.time())
# Out:
# Current Date and Time: 2025-02-12 13:03:16.045493
# Formatted Date: 2025-02-12 13:03:16
# Date After 7 Days: 2025-02-19
# Today's Date: 2025-02-12
# Current Time: 13:03:16.045493

# %% [markdown]
# ### 12) WAP to demonstrate the use of the math module.

# %%
import math

num = float(input("Enter a number: "))

print(f"Square root of {num} is :-  {math.sqrt(num)}")
print(f"Factorial of {num} is :-   {math.factorial(int(num))}")
print(f"Value of Pi is :-   {math.pi}")
print(f"Sine of {num} degrees is :-   {math.sin(math.radians(num))}")
print(f"Logarithm of {num} (base e) is :-  {math.log(num)}")
print(f"Ceiling of {num} is :-   {math.ceil(num)}")
print(f"Floor of {num} is :-   {math.floor(num)}")


# import math

# num = float(input("Enter a number: "))

# # Safeguard against invalid inputs where necessary
# if num < 0:
#     print("Square root is undefined for negative numbers.")
# else:
#     print(f"Square root of {num} is :- {math.sqrt(num)}")

# if num.is_integer() and num >= 0:
#     print(f"Factorial of {int(num)} is :- {math.factorial(int(num))}")
# else:
#     print("Factorial is only defined for non-negative integers.")

# print(f"Value of Pi is :- {math.pi}")
# print(f"Sine of {num} degrees is :- {math.sin(math.radians(num))}")

# if num > 0:
#     print(f"Logarithm of {num} (base e) is :- {math.log(num)}")
# else:
#     print("Logarithm is undefined for non-positive numbers.")

# print(f"Ceiling of {num} is :- {math.ceil(num)}")
# print(f"Floor of {num} is :- {math.floor(num)}")
# Out:
# Enter a number:  50
# Square root of 50.0 is :-  7.0710678118654755
# Factorial of 50.0 is :-   30414093201713378043612608166064768844377641568960512000000000000
# Value of Pi is :-   3.141592653589793
# Sine of 50.0 degrees is :-   0.766044443118978
# Logarithm of 50.0 (base e) is :-  3.912023005428146
# Ceiling of 50.0 is :-   50
# Floor of 50.0 is :-   50
# Enter a number:  20
# Square root of 20.0 is :- 4.47213595499958
# Factorial of 20 is :- 2432902008176640000
# Value of Pi is :- 3.141592653589793
# Sine of 20.0 degrees is :- 0.3420201433256687
# Logarithm of 20.0 (base e) is :- 2.995732273553991
# Ceiling of 20.0 is :- 20
# Floor of 20.0 is :- 20
