# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 4</b></center>
# <center><b><h1>Harsh Vekariya | 23010101297 | 18-12-2024</b></center>
# <pre>

# %% [markdown]
# # String

# %% [markdown]
# ### 01) WAP to check whether the given string is palindrome or not.

# %%
s = input('Enter a string')
if s==s[::-1]:
    print('string is palindrome')
else:
    print('string is not palindrome')
# Out:
# Enter a string deed
# string is palindrome

# %% [markdown]
# ### 02) WAP to reverse the words in the given string.

# %%
s = input('Enter a string:')
li = s. split(' ')
li.reverse()
s2 = ' '.join(li)
print(s2)
# Out:
# Enter a string: i am deep
# deep am i

# %% [markdown]
# ### 03) WAP to remove ith character from given string.

# %%
s = input('Enter a string:')
i = int(input('Delete ith char from string:'))

s = s[0:(i-1)]+s[i:]
print(s)
# Out:
# Enter a string: deep
# Delete ith char from string: 2
# dep

# %% [markdown]
# ### 04) WAP to find length of string without using len function.

# %%
s = input('Enter a string:')
count=0
for i in s:
    count +=1
print('String length is',count)
# Out:
# Enter a string: deep
# String length is 4

# %% [markdown]
# ### 05) WAP to print even length word in string.

# %%
s = input('Enter a string :')
li = s.split()

for i in li:
    if len(i)%2==0:
        print(i,end=' ')
# Out:
# Enter a string : i am deep
# am deep

# %% [markdown]
# ### 06) WAP to count numbers of vowels in given string.

# %%
s = input('Enter a string:')
vowel = 'aeiou'
count=0

for i in s:
    if i in vowel:
        count+=1
print('vowel',count)
# Out:
# Enter a string: deep
# vowel 2

# %% [markdown]
# ### 07) WAP to capitalize the first and last character of each word in a string.

# %%
s = input('Enter a string:')
li = s.split()
s2=''
for i in li:
    if len(i)==1:
        s2=s2+i.upper()+' '
    else:
        s1=i[0].upper()+i[1:len(i)-1]+i[-1].upper()
        s2=s2+s1+' '
print(s2)
# Out:
# Enter a string: i am deep
# I AM DeeP

# %% [markdown]
# ### 08) WAP to convert given array to string.

# %%
s=''
li = ['a','b','c']
s=''.join(li)
print(s)
# Out:
# abc

# %% [markdown]
# ### 09) Check if the password and confirm password is same or not.
# ### In case of only case's mistake, show the error message.

# %%
 password=input("Enter the Password")
 confirm_Password=input("Enter the Confirm Password")
 if password == confirm_Password:
    print("Passwords Match")
 elif password.lower()==confirm_Password.lower():
    print("Password don't match due to case difference")
 else:
    print("Password don't match")
# Out:
# Enter the Password deep
# Enter the Confirm Password deep
# Passwords Match

# %% [markdown]
# ### 10) : Display credit card number.
# ### card no. : 1234 5678 9012 3456
# ### display as  : **** **** **** 3456

# %%
 card_no=input("Enter credit card number(16 digits): ")
 if len(card_no.replace(' ',''))==16:
    last_four=card_no[-4:]
    hidden_part = "**** **** **** "
    print(hidden_part+last_four)
 else:
     print("Invalid Credit Card Number,Please enter 16 digits.")
# Out:
# Enter credit card number(16 digits):  1842789234758917475
# Invalid Credit Card Number,Please enter 16 digits.

# %% [markdown]
# ### 11) : Checking if the two strings are Anagram or not.
# ### s1 = decimal and s2 = medical are Anagram

# %%
s1=input('Enter String-1: ')
s2=input('Enter String-2: ')
isAnagram=True
if len(s1) == len(s2):
    for i in s1:
        if i not in s2:
            isAnagram = False
            print('The strings are not anagram.')
    if isAnagram:
        print('The strings are anagram')
else:
    print('The strings are not anagram')
# Out:
# Enter String-1:  324908
# Enter String-2:  234
# The strings are not anagram

# %% [markdown]
# ### 12) : Rearrange the given string. First lowercase then uppercase alphabets.
# ### input : EHlsarwiwhtwMV
# ### output : lsarwiwhtwEHMV

# %%
 s='EHlsarwiwhtwMV'
 lower=''
 upper=''
for i in s:
    if i.islower():
        lower+=i
    elif i.isupper():
        upper+=i
    output=lower+upper
print(output)
# Out:
# lsarwiwhtwEHMV
