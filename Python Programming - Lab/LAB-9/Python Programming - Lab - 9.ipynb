# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 8</b></center>
# <center><b><h1>Harsh Vekariya | 23010101297 | 29-01-2025</b></center>
# <pre>

# %% [markdown]
# # File I/O

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
Filepointer = open("FileForIO.txt ",'r')
print(Filepointer.read(7))
Filepointer.close()

Filepointer = open("FileForIO.txt ",'r')
for i in Filepointer:
    print(Filepointer.readline())
Filepointer.close()

Filepointer = open("FileForIO.txt ",'r')
print(Filepointer.readlines())
Filepointer.close()
# Out:
# Hi, I a
# I'm Flutter developer and i also learned Web Designing.
#
#
# ['Hi, I am Harsh Vekariya.\n', "I'm Flutter developer and i also learned Web Designing.\n", "I'm in 4th semester Right now.\n"]

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
Filepointer = open("New.txt",'w+')

Filepointer.write("Hello from new File")
Filepointer.seek(0)

print(Filepointer.read())

Filepointer.close()
# Out:
# Hello from new File

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
Filepointer = open("FileForIO.txt ",'r')
for i in range(5):
    print(Filepointer.readline())
Filepointer.close()
# Out:
# Hi, I am Harsh Vekariya.
#
# I'm Flutter developer and i also learned Web Designing.
#
# I'm in 4th semester Right now.
#
# Hello, I am Kishan Akbari.
#
# I'm also a Flutter developer .

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file

# %%
Filepointer = open("FileForIO.txt ",'r')
maxword = 0;

for line in Filepointer:
    for i in line:
        if(len(i) > maxword):
            maxword = len(i)
            word = i

print(f"{maxword},{word}")

# maxword = Filepointer.read().split()
# print(max(maxword,key = len))

Filepointer.close()
# Out:
# 1,H

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
Filepointer = open("FileForIO.txt ",'r')
print(f"No of line is {len(Filepointer.readlines())}")
Filepointer.close()

Filepointer = open("FileForIO.txt ",'r')
print(f"No of words is {len(Filepointer.readline())}")
Filepointer.close()

Filepointer = open("FileForIO.txt ",'r')
print(f"No of characters is {len(Filepointer.read())}")
Filepointer.close()
# Out:
# No of line is 6
# No of words is 25
# No of characters is 238

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
import os

size = os.path.getsize("FileForIO.txt")
print(size)
# Out:
# 238

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def frequency(file_content,specific_word):
    count = file_content.count(specific_word)
    return count


Filepointer = open("FileForIO.txt ",'r')
data = Filepointer.read()
print(frequency(data.split(),'Flutter'))

Filepointer.close()
# Out:
# 2

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
Filepointer = open("FiveMarks",'w+')

for i in range(1,6):
    marks = input(f"Enter a marks of subject no. {i} :")
    Filepointer.write(marks +"\n")

Filepointer.seek(0)

lt = Filepointer.read().split()
         

Filepointer.close()
# Out:
# Enter a marks of subject no. 1 : 10
# Enter a marks of subject no. 2 : 10
# Enter a marks of subject no. 3 : 10
# Enter a marks of subject no. 4 : 10
# Enter a marks of subject no. 5 : 10
# 10

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.
