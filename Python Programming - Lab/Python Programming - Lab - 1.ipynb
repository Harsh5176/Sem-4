# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="10"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 1</b></center>
# <center><b><h1>Harsh Vekariya | 23010101297 | 27-11-2024</b>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World”

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ### 02) WAP to print addition of two numbers with and without using input().

# %%
a = int(input('Enter a number:'))
b = int(input('Enter a number:'))

print('sum = ',a+b)
a,b=10,20
print('sum = ',a+b)
# Out:
# Enter a number: 10
# Enter a number: 10
# sum =  20
# sum =  30

# %% [markdown]
# ### 03) WAP to check the type of the variable.

# %%
a = 10
type(a)
# Out:
# int

# %% [markdown]
# ### 04) WAP to calculate simple interest.

# %%
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest: "))
time = float(input("Enter the time period in years: "))

interest = (principal * rate * time) / 100

print(f"Simple Interest: Rs. {interest:.2f}")
# Out:
# Enter the principal amount:  2
# Enter the rate of interest:  33
# Enter the time period in years:  2
# Simple Interest: Rs. 1.32

# %% [markdown]
# ### 05) WAP to calculate area and perimeter of a circle.

# %%
import math

radius = float(input("Enter the radius of the circle: "))

area = math.pi * radius ** 2

perimeter = 2 * math.pi * radius

print(f"Area of the circle: {area:.2f}")
print(f"Perimeter (circumference) of the circle: {perimeter:.2f}")
# Out:
# Enter the radius of the circle:  45
# Area of the circle: 6361.73
# Perimeter (circumference) of the circle: 282.74

# %% [markdown]
# ### 06) WAP to calculate area of a triangle.

# %%
 height=float(input("Enter the height of the Triangle : "))
 base=float(input("Enter the base of the Triangle : "))
 area=(1/2)*height*base
 print("Area of Triangle:",area)
# Out:
# Enter the height of the Triangle :  23
# Enter the base of the Triangle :  12
# Area of Triangle: 138.0

# %% [markdown]
# ### 07) WAP to compute quotient and remainder.

# %%
 a=int(input("Enter Dividend:"))
 b=int(input("Enter Divisor:"))
 quotient=a//b
 remainder=a%b
 print(f"Quotient is {quotient} and Remainder is {remainder}.")
# Out:
# Enter Dividend: 2
# Enter Divisor: 1
# Quotient is 2 and Remainder is 0.

# %% [markdown]
# ### 08) WAP to convert degree into Fahrenheit and vice versa.

# %%
 cel=int(input("Enter Temperature in degree Celsius (°C):"))
 fahren=int(input("Enter Temperature in degree Fahrenheit (°F):"))
 fahrenheit=(cel*(9/5))+32
 celsius=(fahren-32)*(5/9)
 print(f"{cel} °C = {fahrenheit} °F")
 print(f"{fahren} °F = {celsius} °C")
# Out:
# Enter Temperature in degree Celsius (°C): 23
# Enter Temperature in degree Fahrenheit (°F): 12
# 23 °C = 73.4 °F
# 12 °F = -11.11111111111111 °C

# %% [markdown]
# ### 09) WAP to find the distance between two points in 2-D space.

# %%
x1=int(input("Enter x1 :"))
x2=int(input("Enter x2 :"))            
y1=int(input("Enter y1 :"))
y2=int(input("Enter y2 :"))
distance=((((x2-x1)**2)+((y2-y1)**2))**(1/2))
print(f"Distance between {x1,x2} and {y1,y2} is {round(distance,2)}")
# Out:
# Enter x1 : 12
# Enter x2 : 23
# Enter y1 : 12
# Enter y2 : 43
# Distance between (12, 23) and (12, 43) is 32.89

# %% [markdown]
# ### 10) WAP to print sum of n natural numbers.

# %%
 n=int(input("Enter n up to which you want to sum:"))
 sum=(n*(n+1))/2
 print(f"The Sum of the first {n} numbers is {sum}")
# Out:
# Enter n up to which you want to sum: 23
# The Sum of the first 23 numbers is 276.0

# %% [markdown]
# ### 11) WAP to print sum of square of n natural numbers.

# %%
 n=int(input("Enter n up to which you want to sum of the squares:"))
 sum=(n*(n+1)*(2*n+1))/6
 print(f"The Sum of the Squares of the first {n} numbers is {sum}")
# Out:
# Enter n up to which you want to sum of the squares: 23
# The Sum of the Squares of the first 23 numbers is 4324.0

# %% [markdown]
# ### 12) WAP to concate the first and last name of the student.

# %%
 fname=input("Enter First Name")
 lname=input("Enter Last Name")
 print(fname,lname)
# Out:
# Enter First Name Deep
# Enter Last Name Vaghamashi
# Deep Vaghamashi

# %% [markdown]
# ### 13) WAP to swap two numbers.

# %%
a = input("Enter the value of a = ")
b = input("Enter the value of b = ")

# Display initial values..
print("The initial value of a : "+a)
print("The initial value of b : "+b)
print()

# Swap the values using a temporary variable..
temp = a
a = b
b = temp

#  Display Swapped values..
print("The Swapped value of a :", a)
print("The Swapped value of b :", b)

# Another way to swap numbers..
a = input("a = ")
b = input("b = ")
a, b = b, a
print("a = ", a)
print("b = ", b)
# Out:
# Enter the value of a =  2
# Enter the value of b =  3
# The initial value of a : 2
# The initial value of b : 3
#
# The Swapped value of a : 3
# The Swapped value of b : 2
# a =  2
# b =  3
# a =  3
# b =  2

# %% [markdown]
# ### 14) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km=int(input("Enter Distance in kilometer:"))
print(f"{km} km = {km*1000} m")
print(f"{km} km = {km*1000*100} cm")
print(f"{km} km = {km*1000*3.28} ft")
print(f"{km} km = {km*1000*3.28*12} in")
# Out:
# Enter Distance in kilometer: 1
# 1 km = 1000 m
# 1 km = 100000 cm
# 1 km = 3280.0 ft
# 1 km = 39360.0 in

# %% [markdown]
# ### 15) WAP to get day, month and year from the user and print the date in the given format: 23-11-2024.

# %%
day=input("Enter Day:")
month=input("Enter Month:")
year=input("Enter Year:")
print(day,month,year,sep='-')
# Out:
# Enter Day: 23
# Enter Month: 11
# Enter Year: 2024
# 23-11-2024
